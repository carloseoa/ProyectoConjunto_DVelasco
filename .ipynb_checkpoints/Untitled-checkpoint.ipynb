# %% [markdown]
# En este curso espero aprender muchas cosas sobre programación y perfeccionar mis habilidades obtenidas
#
# # Lo que mas quiero aprender es a simular procesos reales que me ayuden en la vida laboral

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 9, 100)
plt.plot(x, np.exp(x / 3) * np.cos(x) + 10 * np.sin(3 * x), x, x ** 2 / 4)

# %% [markdown]
# $$\textbf{ Primera tarea en parejas para entender mas el funcionamiento de github y gitkraken en formato LATEX}$$

# %% [markdown]
# \begin{itemize}
#
# \item Espero poder entender de una manera mas clara cada linea de cogido y verlo como un lenguaje y no solo machete
#
# \item Queremos aprender a ser mas optimos en la solucion de problemas
#
# \item Queremos saber simplificar lineas de codigo para que sea mas amigable con el usuario.

# %%
   __
                     .'  '.
                 _.-'/  |  \
    ,        _.-"  ,|  /  0 `-.
    |\    .-"       `--""-.__.'=====================-,
    \ '-'`        .___.--._)=========================|
     \            .'      |                          |
      |     /,_.-'        |       Espectativas       |
    _/   _.'(             |           DE             |
   /  ,-' \  \            |        Clase             |
   \  \    `-'            |                          |
    `-'                   '--------------------------'
